# %% [markdown]
# # NHTSA API SQL Analysis
#
# This notebook contains descriptive and diagnostic analytics queries against the `nhtsa_recalls_summary` and `nhtsa_recalls_detail` tables.

# %% [markdown]
# ## Setup
# Load credentials from environment variables and establish a database connection.

# %%
import os
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

PG_user = os.getenv('PG_USER')
PG_password = os.getenv('PG_PASSWORD')
PG_host = os.getenv('PG_HOST')
PG_DB = os.getenv('PG_DB')

# Create database engine
engine = create_engine(f"postgresql://{PG_user}:{PG_password}@{PG_host}/{PG_DB}")

# Display all rows in pandas DataFrame
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Query 1: Descriptive Analytics Query
# **Business Question:** Which makes and models have the highest number of recalls?

# %%
sql_query = '''
-- Descriptive Analytics Query for NHTSA Recalls (with proper quoting)
SELECT
    "Make"            AS make,
    "Model"           AS model,
    "RecallCount_2000_2025" AS recall_count
FROM sql_project."nhtsa_recalls_summary"
ORDER BY recall_count DESC;
'''
df1 = pd.read_sql(sql_query, engine)
df1
# Out:
#       make                    model  recall_count
# 0   Toyota                   Tundra           218
# 1   Toyota                   Tacoma           151
# 2   Toyota                   Sienna           148
# 3   Toyota                  Corolla           145
# 4   Toyota                     RAV4           130
# 5   Toyota                  Sequoia           128
# 6   Toyota                  4Runner           120
# 7   Toyota               Highlander           113
# 8   Toyota                    Camry           103
# 9   Toyota                    Prius            84
# 10  Toyota                   Avalon            81
# 11  Toyota                    Yaris            68
# 12  Toyota               FJ Cruiser            66
# 13  Toyota             Land Cruiser            52
# 14  Toyota        Highlander Hybrid            45
# 15  Toyota                    Venza            35
# 16  Toyota             Camry Hybrid            29
# 17  Toyota                   Matrix            27
# 18  Toyota            Avalon Hybrid            18
# 19  Toyota            Tundra Hybrid            16
# 20  Toyota                  Prius v            15
# 21  Toyota                    Supra            12
# 22  Toyota              RAV4 Hybrid            11
# 23  Toyota                  RAV4 EV             9
# 24  Toyota           Corolla Hybrid             7
# 25  Toyota               RAV4 Prime             7
# 26  Toyota                   Celica             7
# 27  Toyota              Prius Prime             7
# 28  Toyota                     Echo             7
# 29  Toyota            Sienna Hybrid             6
# 30  Toyota            Corolla Cross             6
# 31  Toyota     Corolla Cross Hybrid             6
# 32  Toyota                     C-HR             6
# 33  Toyota                  Prius c             5
# 34  Toyota                    Crown             4
# 35  Toyota                       86             4
# 36  Toyota        Corolla Hatchback             3
# 37  Toyota                     GR86             3
# 38  Toyota                     bZ4X             3
# 39  Toyota                    Mirai             3
# 40  Toyota         Grand Highlander             2
# 41  Toyota  Grand Highlander Hybrid             2
# 42  Toyota               GR Corolla             2
# 43  Toyota                 GR Supra             1
# 44  Toyota              Yaris Verso             0
# 45  Toyota                   Aurion             0
# 46  Toyota                    Auris             0
# 47  Toyota                   Avanza             0
# 48  Toyota                  Avensis             0
# 49  Toyota                    Carib             0
# 50  Toyota                   Carina             0
# 51  Toyota                 Cavalier             0
# 52  Toyota            Corolla Verso             0
# 53  Toyota                 Cressida             0
# 54  Toyota                     Dyna             0
# 55  Toyota                    Etios             0
# 56  Toyota               Etios Liva             0
# 57  Toyota                     FJ40             0
# 58  Toyota                 Fortuner             0
# 59  Toyota                  Harrier             0
# 60  Toyota                    Hiace             0
# 61  Toyota                    Hilux             0
# 62  Toyota                   Innova             0
# 63  Toyota                      iQ2             0
# 64  Toyota                 King Cab             0
# 65  Toyota                   Mark X             0
# 66  Toyota                      MR2             0
# 67  Toyota                    Paseo             0
# 68  Toyota                   Pickup             0
# 69  Toyota                    Prado             0
# 70  Toyota                   Premio             0
# 71  Toyota                   Previa             0
# 72  Toyota            Prius Plug-in             0
# 73  Toyota                     Raum             0
# 74  Toyota                    Scion             0
# 75  Toyota                       Se             0
# 76  Toyota                   Solara             0
# 77  Toyota                 Sprinter             0
# 78  Toyota                     T100             0
# 79  Toyota                   Tarago             0
# 80  Toyota                   Tercel             0
# 81  Toyota                      Van             0
# 82  Toyota                    Verso             0
# 83  Toyota                     Vitz             0
# 84  Toyota                   Windom             0
# 85  Toyota          Yaris Hatchback             0

# %% [markdown]
# ### Insight
#
# Five Toyota nameplates (Tundra 218, Tacoma 151, Sienna 148, Corolla 145, RAV4 130) make up ~41 % of all Toyota recalls
#
# ### Recommendation
#
# Place these models at the top of the recall-reduction backlog: build a quick dashboard that tracks their open campaigns and highlights any spike > 5 recalls/quarter.
#
# ### Prediction
#
# Concentrated effort on just these five programs could trim Toyota’s annual recall volume by a large amount.

# %% [markdown]
# ## Query 2: Diagnostic Analytics Query
# **Business Question:** For the top 5 recalled models, which components are most frequently recalled and what percentage do they represent?

# %%
sql_query = '''
WITH top_models AS (
  SELECT
    "Make",
    "Model",
    "RecallCount_2000_2025" AS recall_count
  FROM sql_project."nhtsa_recalls_summary"
  ORDER BY recall_count DESC
  LIMIT 5
),
component_counts AS (
  SELECT
    "Manufacturer",
    "Model",
    "Component",
    COUNT(*) AS component_count
  FROM sql_project."nhtsa_recalls_detail"
  GROUP BY "Manufacturer", "Model", "Component"
)
SELECT
  tm."Make"  AS make,
  tm."Model" AS model,
  cc."Component"          AS component,
  cc.component_count      AS count,
  cc.component_count * 100.0
        / SUM(cc.component_count) OVER (PARTITION BY tm."Make", tm."Model")
        AS pct_of_model_recalls
FROM top_models tm
JOIN component_counts cc
  ON LOWER(cc."Model") = LOWER(tm."Model")
 AND LOWER(cc."Manufacturer") ILIKE '%%' || LOWER(tm."Make") || '%%'   -- note the doubled %%
ORDER BY tm."Model", count DESC;
'''
df2 = pd.read_sql(sql_query, engine)
df2
# Out:
#        make    model                                          component  \
# 0    Toyota  Corolla    AIR BAGS:FRONTAL:PASSENGER SIDE:INFLATOR MODULE
# 1    Toyota  Corolla                                           AIR BAGS
# 2    Toyota  Corolla         AIR BAGS: AIR BAG/RESTRAINT CONTROL MODULE
# 3    Toyota  Corolla                             EQUIPMENT:OTHER:LABELS
# 4    Toyota  Corolla                             EQUIPMENT:OTHER:LABELS
# 5    Toyota  Corolla            VEHICLE SPEED CONTROL:ACCELERATOR PEDAL
# 6    Toyota  Corolla                          ENGINE AND ENGINE COOLING
# 7    Toyota  Corolla            SEATS:FRONT ASSEMBLY:SEAT HEATER/COOLER
# 8    Toyota  Corolla       VISIBILITY:POWER WINDOW DEVICES AND CONTROLS
# 9    Toyota  Corolla    AIR BAGS:FRONTAL:SENSOR/CONTROL MODULE-INACTIVE
# 10   Toyota  Corolla           FUEL SYSTEM, GASOLINE:DELIVERY:FUEL PUMP
# 11   Toyota  Corolla                             EQUIPMENT:OTHER:LABELS
# 12   Toyota  Corolla                                           STEERING
# 13   Toyota  Corolla       AIR BAGS:FRONTAL:DRIVER SIDE:INFLATOR MODULE
# 14   Toyota  Corolla            AIR BAGS:SENSOR:OCCUPANT CLASSIFICATION
# 15   Toyota  Corolla                                   AIR BAGS:FRONTAL
# 16   Toyota  Corolla                    STRUCTURE:BODY:ROOF AND PILLARS
# 17   Toyota  Corolla                                    STEERING:COLUMN
# 18   Toyota  Corolla                             EQUIPMENT:OTHER:LABELS
# 19   Toyota  Corolla      SERVICE BRAKES, HYDRAULIC:POWER ASSIST:VACUUM
# 20   Toyota  Corolla                        VISIBILITY:GLASS, SIDE/REAR
# 21   Toyota  Corolla             SEAT BELTS: REAR/OTHER:BUCKLE ASSEMBLY
# 22   Toyota  Corolla                          POWER TRAIN:AXLE ASSEMBLY
# 23   Toyota  Corolla               TIRES:TEMPORARY/EMERGENCY SPARE TIRE
# 24   Toyota  Corolla                                             WHEELS
# 25   Toyota  Corolla   VISIBILITY:WINDSHIELD WIPER/WASHER:SWITCH/WIRING
# 26   Toyota  Corolla  POWER TRAIN:AUTOMATIC TRANSMISSION:TORQUE CONV...
# 27   Toyota  Corolla                             EQUIPMENT:OTHER:LABELS
# 28   Toyota     RAV4                                    SUSPENSION:REAR
# 29   Toyota     RAV4            SEATS:FRONT ASSEMBLY:SEAT HEATER/COOLER
# 30   Toyota     RAV4       VISIBILITY:POWER WINDOW DEVICES AND CONTROLS
# 31   Toyota     RAV4            VEHICLE SPEED CONTROL:ACCELERATOR PEDAL
# 32   Toyota     RAV4                              SEAT BELTS:REAR/OTHER
# 33   Toyota     RAV4              ELECTRICAL SYSTEM:12V/24V/48V BATTERY
# 34   Toyota     RAV4                             EQUIPMENT:OTHER:LABELS
# 35   Toyota     RAV4                             EQUIPMENT:OTHER:LABELS
# 36   Toyota     RAV4       AIR BAGS:FRONTAL:DRIVER SIDE:INFLATOR MODULE
# 37   Toyota     RAV4                             EQUIPMENT:OTHER:LABELS
# 38   Toyota     RAV4              STEERING:ELECTRIC POWER ASSIST SYSTEM
# 39   Toyota     RAV4                                   VISIBILITY/WIPER
# 40   Toyota     RAV4    AIR BAGS:FRONTAL:SENSOR/CONTROL MODULE-INACTIVE
# 41   Toyota     RAV4                             EQUIPMENT:OTHER:LABELS
# 42   Toyota     RAV4                                           AIR BAGS
# 43   Toyota     RAV4                                    TRAILER HITCHES
# 44   Toyota     RAV4             SUSPENSION:FRONT:CONTROL ARM:LOWER ARM
# 45   Toyota     RAV4    AIR BAGS:FRONTAL:PASSENGER SIDE:INFLATOR MODULE
# 46   Toyota     RAV4           FUEL SYSTEM, GASOLINE:DELIVERY:FUEL PUMP
# 47   Toyota     RAV4                                          EQUIPMENT
# 48   Toyota     RAV4            AIR BAGS:SENSOR:OCCUPANT CLASSIFICATION
# 49   Toyota     RAV4                          ENGINE AND ENGINE COOLING
# 50   Toyota     RAV4                                        TIRES:VALVE
# 51   Toyota     RAV4                     SERVICE BRAKES, AIR:DISC:ROTOR
# 52   Toyota     RAV4                             EQUIPMENT:OTHER:LABELS
# 53   Toyota     RAV4  POWER TRAIN:AUTOMATIC TRANSMISSION:PARK/NEUTRA...
# 54   Toyota     RAV4                               AIR BAGS:SIDE/WINDOW
# 55   Toyota     RAV4                                              TIRES
# 56   Toyota     RAV4                             EQUIPMENT:OTHER:LABELS
# 57   Toyota     RAV4                                   AIR BAGS:FRONTAL
# 58   Toyota     RAV4       BACK OVER PREVENTION: SENSING SYSTEM: CAMERA
# 59   Toyota     RAV4  SERVICE BRAKES, HYDRAULIC:FOUNDATION COMPONENT...
# 60   Toyota     RAV4  SERVICE BRAKES, HYDRAULIC:ANTILOCK/TRACTION CO...
# 61   Toyota     RAV4               TIRES:TEMPORARY/EMERGENCY SPARE TIRE
# 62   Toyota     RAV4  SERVICE BRAKES, HYDRAULIC:ANTILOCK/TRACTION CO...
# 63   Toyota     RAV4  AIR BAGS:SENSOR:OCCUPANT CLASSIFICATION:FRONT ...
# 64   Toyota   Sienna            SEATS:FRONT ASSEMBLY:SEAT HEATER/COOLER
# 65   Toyota   Sienna    AIR BAGS:FRONTAL:PASSENGER SIDE:INFLATOR MODULE
# 66   Toyota   Sienna                                          STRUCTURE
# 67   Toyota   Sienna                             EQUIPMENT:OTHER:LABELS
# 68   Toyota   Sienna                 POWER TRAIN:AUTOMATIC TRANSMISSION
# 69   Toyota   Sienna                             EQUIPMENT:OTHER:LABELS
# 70   Toyota   Sienna               TIRES:TEMPORARY/EMERGENCY SPARE TIRE
# 71   Toyota   Sienna           FUEL SYSTEM, GASOLINE:DELIVERY:FUEL PUMP
# 72   Toyota   Sienna                             EQUIPMENT:OTHER:LABELS
# 73   Toyota   Sienna                                STRUCTURE:BODY:DOOR
# 74   Toyota   Sienna                             EQUIPMENT:OTHER:LABELS
# 75   Toyota   Sienna    AIR BAGS:FRONTAL:SENSOR/CONTROL MODULE-INACTIVE
# 76   Toyota   Sienna                             EQUIPMENT:OTHER:LABELS
# 77   Toyota   Sienna                  STRUCTURE:BODY:HATCHBACK/LIFTGATE
# 78   Toyota   Sienna  ELECTRONIC STABILITY CONTROL (ESC):CONTROL MOD...
# 79   Toyota   Sienna                                         SEAT BELTS
# 80   Toyota   Sienna                          ENGINE AND ENGINE COOLING
# 81   Toyota   Sienna                               AIR BAGS:SIDE/WINDOW
# 82   Toyota   Sienna                        STRUCTURE:FRAME AND MEMBERS
# 83   Toyota   Sienna  FUEL SYSTEM, GASOLINE:DELIVERY:HOSES, LINES/PI...
# 84   Toyota   Sienna                               EQUIPMENT:ELECTRICAL
# 85   Toyota   Sienna      SERVICE BRAKES, HYDRAULIC:PEDALS AND LINKAGES
# 86   Toyota   Sienna                    SEAT BELTS:REAR/OTHER:ANCHORAGE
# 87   Toyota   Sienna                   POWER TRAIN:DRIVELINE:DRIVESHAFT
# 88   Toyota   Sienna      SERVICE BRAKES, HYDRAULIC:POWER ASSIST:VACUUM
# 89   Toyota   Sienna               TIRES:TEMPORARY/EMERGENCY SPARE TIRE
# 90   Toyota   Sienna  POWER TRAIN:AUTOMATIC TRANSMISSION:GEAR POSITI...
# 91   Toyota   Sienna            VEHICLE SPEED CONTROL:ACCELERATOR PEDAL
# 92   Toyota   Sienna                             EQUIPMENT:OTHER:LABELS
# 93   Toyota   Sienna                                   SEAT BELTS:FRONT
# 94   Toyota   Sienna                    STRUCTURE:BODY:ROOF AND PILLARS
# 95   Toyota   Sienna        FUEL SYSTEM, GASOLINE:STORAGE:TANK ASSEMBLY
# 96   Toyota   Sienna                                             WHEELS
# 97   Toyota   Sienna                    STRUCTURE:BODY:ROOF AND PILLARS
# 98   Toyota   Sienna                    STRUCTURE:BODY:ROOF AND PILLARS
# 99   Toyota   Tacoma            SEATS:FRONT ASSEMBLY:SEAT HEATER/COOLER
# 100  Toyota   Tacoma                             EQUIPMENT:OTHER:LABELS
# 101  Toyota   Tacoma  SUSPENSION:REAR:SPRINGS:LEAF SPRING ASSEMBLY:LEAF
# 102  Toyota   Tacoma                                         SEAT BELTS
# 103  Toyota   Tacoma                             EQUIPMENT:OTHER:LABELS
# 104  Toyota   Tacoma          STRUCTURE:BODY:HOOD:HINGE AND ATTACHMENTS
# 105  Toyota   Tacoma            VEHICLE SPEED CONTROL:ACCELERATOR PEDAL
# 106  Toyota   Tacoma           FUEL SYSTEM, GASOLINE:DELIVERY:FUEL PUMP
# 107  Toyota   Tacoma                             EQUIPMENT:OTHER:LABELS
# 108  Toyota   Tacoma                             EQUIPMENT:OTHER:LABELS
# 109  Toyota   Tacoma                                   AIR BAGS:FRONTAL
# 110  Toyota   Tacoma    AIR BAGS:FRONTAL:SENSOR/CONTROL MODULE-INACTIVE
# 111  Toyota   Tacoma                             EQUIPMENT:OTHER:LABELS
# 112  Toyota   Tacoma                                             ENGINE
# 113  Toyota   Tacoma      SUSPENSION:FRONT:CONTROL ARM:LOWER BALL JOINT
# 114  Toyota   Tacoma               TIRES:TEMPORARY/EMERGENCY SPARE TIRE
# 115  Toyota   Tacoma   TIRES:PRESSURE MONITORING AND REGULATING SYSTEMS
# 116  Toyota   Tacoma                             EQUIPMENT:OTHER:LABELS
# 117  Toyota   Tacoma                                           AIR BAGS
# 118  Toyota   Tacoma  FUEL SYSTEM, GASOLINE:DELIVERY:HOSES, LINES/PI...
# 119  Toyota   Tacoma  SERVICE BRAKES, HYDRAULIC:FOUNDATION COMPONENT...
# 120  Toyota   Tacoma  SERVICE BRAKES, HYDRAULIC:FOUNDATION COMPONENT...
# 121  Toyota   Tacoma  SERVICE BRAKES, HYDRAULIC:ANTILOCK/TRACTION CO...
# 122  Toyota   Tacoma            POWER TRAIN:DRIVELINE:DIFFERENTIAL UNIT
# 123  Toyota   Tacoma                                          EQUIPMENT
# 124  Toyota   Tacoma                          POWER TRAIN:AXLE ASSEMBLY
# 125  Toyota   Tacoma                    CHILD SEAT:VEHICLE LATCH ANCHOR
# 126  Toyota   Tacoma       AIR BAGS:FRONTAL:DRIVER SIDE:INFLATOR MODULE
# 127  Toyota   Tacoma               TIRES:TEMPORARY/EMERGENCY SPARE TIRE
# 128  Toyota   Tacoma                                    STEERING:COLUMN
# 129  Toyota   Tacoma                                   SEAT BELTS:FRONT
# 130  Toyota   Tacoma                                         TIRES:BEAD
# 131  Toyota   Tacoma                   POWER TRAIN:DRIVELINE:DRIVESHAFT
# 132  Toyota   Tacoma      SERVICE BRAKES, HYDRAULIC:POWER ASSIST:VACUUM
# 133  Toyota   Tacoma                                    TRAILER HITCHES
# 134  Toyota   Tacoma                                      PARKING BRAKE
# 135  Toyota   Tacoma                                              TIRES
# 136  Toyota   Tacoma                              AIR BAGS:KNEE BOLSTER
# 137  Toyota   Tacoma                                     TIRES:SIDEWALL
# 138  Toyota   Tacoma                              POWER TRAIN:DRIVELINE
# 139  Toyota   Tundra             STEERING:HYDRAULIC POWER ASSIST SYSTEM
# 140  Toyota   Tundra            SEATS:FRONT ASSEMBLY:SEAT HEATER/COOLER
# 141  Toyota   Tundra                             EQUIPMENT:OTHER:LABELS
# 142  Toyota   Tundra                                           AIR BAGS
# 143  Toyota   Tundra            VEHICLE SPEED CONTROL:ACCELERATOR PEDAL
# 144  Toyota   Tundra                             EQUIPMENT:OTHER:LABELS
# 145  Toyota   Tundra    AIR BAGS:FRONTAL:PASSENGER SIDE:INFLATOR MODULE
# 146  Toyota   Tundra                             EQUIPMENT:OTHER:LABELS
# 147  Toyota   Tundra      SUSPENSION:FRONT:CONTROL ARM:LOWER BALL JOINT
# 148  Toyota   Tundra                             EQUIPMENT:OTHER:LABELS
# 149  Toyota   Tundra       VISIBILITY:POWER WINDOW DEVICES AND CONTROLS
# 150  Toyota   Tundra                             EQUIPMENT:OTHER:LABELS
# 151  Toyota   Tundra   TIRES:PRESSURE MONITORING AND REGULATING SYSTEMS
# 152  Toyota   Tundra                       WHEELS:LUGS/NUTS/BOLTS/STUDS
# 153  Toyota   Tundra    AIR BAGS:FRONTAL:SENSOR/CONTROL MODULE-INACTIVE
# 154  Toyota   Tundra           FUEL SYSTEM, GASOLINE:DELIVERY:FUEL PUMP
# 155  Toyota   Tundra   TIRES:PRESSURE MONITORING AND REGULATING SYSTEMS
# 156  Toyota   Tundra      STRUCTURE:FRAME AND MEMBERS:UNDERBODY SHIELDS
# 157  Toyota   Tundra                             EQUIPMENT:OTHER:LABELS
# 158  Toyota   Tundra                       EXTERIOR LIGHTING:HEADLIGHTS
# 159  Toyota   Tundra   TIRES:PRESSURE MONITORING AND REGULATING SYSTEMS
# 160  Toyota   Tundra                                             WHEELS
# 161  Toyota   Tundra                    AIR BAGS:ON-OFF SWITCH ASSEMBLY
# 162  Toyota   Tundra                 POWER TRAIN:AUTOMATIC TRANSMISSION
# 163  Toyota   Tundra                               AIR BAGS:SIDE/WINDOW
# 164  Toyota   Tundra                      EXTERIOR LIGHTING:TURN SIGNAL
# 165  Toyota   Tundra                         ELECTRICAL SYSTEM:SOFTWARE
# 166  Toyota   Tundra  ENGINE AND ENGINE COOLING:ENGINE:HARD PARTS IN...
# 167  Toyota   Tundra                             STRUCTURE:BODY:BUMPERS
# 168  Toyota   Tundra           ENGINE AND ENGINE COOLING:EXHAUST SYSTEM
# 169  Toyota   Tundra                       WHEELS:LUGS/NUTS/BOLTS/STUDS
# 170  Toyota   Tundra        ELECTRICAL SYSTEM: INSTRUMENT CLUSTER/PANEL
# 171  Toyota   Tundra                   POWER TRAIN:DRIVELINE:DRIVESHAFT
# 172  Toyota   Tundra  FUEL SYSTEM, GASOLINE:DELIVERY:HOSES, LINES/PI...
# 173  Toyota   Tundra                                     STRUCTURE:BODY
# 174  Toyota   Tundra                       WHEELS:LUGS/NUTS/BOLTS/STUDS
# 175  Toyota   Tundra                          SERVICE BRAKES, HYDRAULIC
# 176  Toyota   Tundra                                     TIRES:SIDEWALL
# 177  Toyota   Tundra                                   AIR BAGS:FRONTAL
# 178  Toyota   Tundra                 ELECTRONIC STABILITY CONTROL (ESC)
# 179  Toyota   Tundra     ELECTRICAL SYSTEM:ADAS:PARKING ASSIST:SOFTWARE
# 180  Toyota   Tundra               POWER TRAIN:AXLE ASSEMBLY:AXLE SHAFT
# 181  Toyota   Tundra                            SEATS:MID/REAR ASSEMBLY
# 182  Toyota   Tundra               POWER TRAIN:AXLE ASSEMBLY:AXLE SHAFT
# 183  Toyota   Tundra                      EXTERIOR LIGHTING:TAIL LIGHTS
# 184  Toyota   Tundra                                    TRAILER HITCHES
# 185  Toyota   Tundra                              AIR BAGS:KNEE BOLSTER
# 186  Toyota   Tundra               TIRES:TEMPORARY/EMERGENCY SPARE TIRE
#
#      count  pct_of_model_recalls
# 0       34             29.310345
# 1       12             10.344828
# 2        9              7.758621
# 3        5              4.310345
# 4        5              4.310345
# 5        4              3.448276
# 6        4              3.448276
# 7        4              3.448276
# 8        4              3.448276
# 9        4              3.448276
# 10       3              2.586207
# 11       3              2.586207
# 12       2              1.724138
# 13       2              1.724138
# 14       2              1.724138
# 15       2              1.724138
# 16       2              1.724138
# 17       2              1.724138
# 18       2              1.724138
# 19       2              1.724138
# 20       2              1.724138
# 21       1              0.862069
# 22       1              0.862069
# 23       1              0.862069
# 24       1              0.862069
# 25       1              0.862069
# 26       1              0.862069
# 27       1              0.862069
# 28      18             13.846154
# 29      11              8.461538
# 30       9              6.923077
# 31       7              5.384615
# 32       7              5.384615
# 33       6              4.615385
# 34       6              4.615385
# 35       6              4.615385
# 36       6              4.615385
# 37       6              4.615385
# 38       4              3.076923
# 39       4              3.076923
# 40       4              3.076923
# 41       4              3.076923
# 42       3              2.307692
# 43       3              2.307692
# 44       2              1.538462
# 45       2              1.538462
# 46       2              1.538462
# 47       2              1.538462
# 48       2              1.538462
# 49       2              1.538462
# 50       1              0.769231
# 51       1              0.769231
# 52       1              0.769231
# 53       1              0.769231
# 54       1              0.769231
# 55       1              0.769231
# 56       1              0.769231
# 57       1              0.769231
# 58       1              0.769231
# 59       1              0.769231
# 60       1              0.769231
# 61       1              0.769231
# 62       1              0.769231
# 63       1              0.769231
# 64      14             10.769231
# 65      11              8.461538
# 66      11              8.461538
# 67      10              7.692308
# 68      10              7.692308
# 69       8              6.153846
# 70       8              6.153846
# 71       7              5.384615
# 72       6              4.615385
# 73       6              4.615385
# 74       5              3.846154
# 75       4              3.076923
# 76       3              2.307692
# 77       3              2.307692
# 78       2              1.538462
# 79       2              1.538462
# 80       2              1.538462
# 81       1              0.769231
# 82       1              0.769231
# 83       1              0.769231
# 84       1              0.769231
# 85       1              0.769231
# 86       1              0.769231
# 87       1              0.769231
# 88       1              0.769231
# 89       1              0.769231
# 90       1              0.769231
# 91       1              0.769231
# 92       1              0.769231
# 93       1              0.769231
# 94       1              0.769231
# 95       1              0.769231
# 96       1              0.769231
# 97       1              0.769231
# 98       1              0.769231
# 99      12              8.633094
# 100      8              5.755396
# 101      7              5.035971
# 102      7              5.035971
# 103      7              5.035971
# 104      6              4.316547
# 105      6              4.316547
# 106      6              4.316547
# 107      6              4.316547
# 108      5              3.597122
# 109      5              3.597122
# 110      4              2.877698
# 111      4              2.877698
# 112      4              2.877698
# 113      4              2.877698
# 114      4              2.877698
# 115      4              2.877698
# 116      4              2.877698
# 117      3              2.158273
# 118      3              2.158273
# 119      2              1.438849
# 120      2              1.438849
# 121      2              1.438849
# 122      2              1.438849
# 123      2              1.438849
# 124      2              1.438849
# 125      2              1.438849
# 126      2              1.438849
# 127      2              1.438849
# 128      2              1.438849
# 129      1              0.719424
# 130      1              0.719424
# 131      1              0.719424
# 132      1              0.719424
# 133      1              0.719424
# 134      1              0.719424
# 135      1              0.719424
# 136      1              0.719424
# 137      1              0.719424
# 138      1              0.719424
# 139     30             15.306122
# 140     12              6.122449
# 141     11              5.612245
# 142      8              4.081633
# 143      8              4.081633
# 144      7              3.571429
# 145      7              3.571429
# 146      6              3.061224
# 147      6              3.061224
# 148      6              3.061224
# 149      5              2.551020
# 150      5              2.551020
# 151      5              2.551020
# 152      5              2.551020
# 153      4              2.040816
# 154      4              2.040816
# 155      4              2.040816
# 156      4              2.040816
# 157      4              2.040816
# 158      4              2.040816
# 159      3              1.530612
# 160      3              1.530612
# 161      3              1.530612
# 162      3              1.530612
# 163      3              1.530612
# 164      3              1.530612
# 165      3              1.530612
# 166      2              1.020408
# 167      2              1.020408
# 168      2              1.020408
# 169      2              1.020408
# 170      2              1.020408
# 171      2              1.020408
# 172      2              1.020408
# 173      2              1.020408
# 174      2              1.020408
# 175      1              0.510204
# 176      1              0.510204
# 177      1              0.510204
# 178      1              0.510204
# 179      1              0.510204
# 180      1              0.510204
# 181      1              0.510204
# 182      1              0.510204
# 183      1              0.510204
# 184      1              0.510204
# 185      1              0.510204
# 186      1              0.510204

# %%
df2.groupby(['model']).apply(
    lambda g: g.nlargest(1, 'pct_of_model_recalls')[['component',
                                                     'pct_of_model_recalls']]
)
# Out:
# /tmp/ipykernel_18341/4126860498.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df2.groupby(['model']).apply(
#                                                    component  \
# model
# Corolla 0    AIR BAGS:FRONTAL:PASSENGER SIDE:INFLATOR MODULE
# RAV4    28                                   SUSPENSION:REAR
# Sienna  64           SEATS:FRONT ASSEMBLY:SEAT HEATER/COOLER
# Tacoma  99           SEATS:FRONT ASSEMBLY:SEAT HEATER/COOLER
# Tundra  139           STEERING:HYDRAULIC POWER ASSIST SYSTEM
#
#              pct_of_model_recalls
# model
# Corolla 0               29.310345
# RAV4    28              13.846154
# Sienna  64              10.769231
# Tacoma  99               8.633094
# Tundra  139             15.306122

# %% [markdown]
# ### Insight
#
# Each high-recall model shows a single dominant component family—e.g., passenger air-bag inflators drive 29 % of Corolla recalls, rear-suspension links 14 % of RAV4, hydraulic power-assist 15 % of Tundra.
#
# ### Recommendation
#
# Run root-cause analyses starting with the top component for each model; prioritize supplier audits, design reviews, or process-control checks on those items first.
#
# ### Prediction
#
# Eliminating the leading component issue per model would cut total recalls for that vehicle line, generating potential savings.
